# %%
# %run TradeSPChanges.ipy
# %matplotlib inline
# Out:
# ERROR: File `'TradeSPChanges.ipy.py'` not found.

# %%
# Get data
date_diff = 30
file_name = 'GetData_20132016.sql'
data = get_stock_data(file_name, date_diff)

# %%
fixed_trade_amount = 10000
strategy = 0
file_name = 'New_Strategy0.txt'
results = run_trading_strategy(data, strategy=strategy, log_file=file_name)
# Out:
# Average return: -43.97 / -0.44%
# Stddev return: 309.32 / 3.09%
# Max return: 1014.41
# Min return: -765.84
# Total trades: 57
# Winning trades: 22
# Losing trades: 35
# Flat trades: 0
# Average long return: 18.97 / 0.19%
# Average short return: -62.93 / -0.63%

# %%
fixed_trade_amount = 10000
strategy = 1
file_name = 'New_Strategy1.txt'
results = run_trading_strategy(data, strategy=strategy, log_file=file_name)
# Out:
# Average return: -64.92 / -0.65%
# Stddev return: 1044.03 / 10.44%
# Max return: 6503.48
# Min return: -1865.63
# Total trades: 57
# Winning trades: 19
# Losing trades: 38
# Flat trades: 0
# Average long return: 19.18 / 0.19%
# Average short return: -84.10 / -0.84%

# %%
fixed_trade_amount = 10000
strategy = 2
file_name = 'New_Strategy2.txt'
results = run_trading_strategy(data, strategy=strategy, log_file=file_name)
# Out:
# Average return: -87.95 / -0.88%
# Stddev return: 1436.34 / 14.36%
# Max return: 6503.48
# Min return: -1865.63
# Total trades: 29
# Winning trades: 10
# Losing trades: 19
# Flat trades: 0
# Average long return: 29.11 / 0.29%
# Average short return: -117.06 / -1.17%

# %%
fixed_trade_amount = 10000
strategy = 0
file_name = 'New_Strategy0_Timing.txt'
results = run_trading_strategy(data, strategy=strategy, log_file=file_name, timing = True)
# Out:
# Average return: 161.09 / 1.61%
# Stddev return: 402.41 / 4.02%
# Max return: 1200.20
# Min return: -535.38
# Total trades: 57
# Winning trades: 35
# Losing trades: 22
# Flat trades: 0
# Average long return: 229.67 / 2.30%
# Average short return: -68.59 / -0.69%

# %%
fixed_trade_amount = 10000
strategy = 1
file_name = 'New_Strategy1_Timing.txt'
results = run_trading_strategy(data, strategy=strategy, log_file=file_name, timing = True)
# Out:
# Average return: 181.77 / 1.82%
# Stddev return: 1054.56 / 10.55%
# Max return: 6704.17
# Min return: -1657.89
# Total trades: 57
# Winning trades: 31
# Losing trades: 26
# Flat trades: 0
# Average long return: 230.82 / 2.31%
# Average short return: -49.05 / -0.49%

# %%
fixed_trade_amount = 10000
strategy = 2
file_name = 'New_Strategy2_Timing.txt'
results = run_trading_strategy(data, strategy=strategy, log_file=file_name, timing = True)
# Out:
# Average return: 168.44 / 1.68%
# Stddev return: 1419.37 / 14.19%
# Max return: 6704.17
# Min return: -1657.89
# Total trades: 29
# Winning trades: 15
# Losing trades: 14
# Flat trades: 0
# Average long return: 219.64 / 2.20%
# Average short return: -51.20 / -0.51%
