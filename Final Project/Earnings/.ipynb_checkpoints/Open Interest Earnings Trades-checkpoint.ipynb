# %% [markdown]
# # Following the Options
#
# Strategy: Buy equity when call open interest goes up (by some amount) after earnings release, and short equity when put open interest goes up after earnings release.

# %%
import sys
sys.path.append('../../utils/')

from query import query_dataframe, get_connection
from trading_days import TradingDay

date_format = '%Y-%m-%d'

# %%
import pandas as pd

earnings_dates = pd.read_csv('all_earnings.csv', index_col=0)
earnings_dates['NormDate'] = pd.to_datetime(
    earnings_dates['NormDate'],
    #format="%m-%d-%Y",
    format='%Y-%m-%d',
    errors='coerce'
)

earnings_dates = earnings_dates[(earnings_dates['Date'] > '2011-01-01') &
                                (earnings_dates['Date'] < '2014-01-01')]
earnings_dates['BeforeOpen'] = earnings_dates['BeforeOpen'].astype(bool)

# %%
import sqlalchemy
earnings_dates.to_sql(
    'bcs2149_earnings', get_connection(),
    dtype={
        'Date': sqlalchemy.types.DATE,
        'NormDate': sqlalchemy.types.DATE,
        'Ticker': sqlalchemy.types.VARCHAR
    }
)

# %%
# %%time
base_query = open('OpenInterestEarnings.sql', 'r').read()
query_example = base_query.format(
    window=4,
    days_prior=1,
    days_after=30,
    tickers=','.join(["'AAPL'", "'MSFT'", "'C'", "'REGN'"])
)

example_earnings = query_dataframe(query_example)
# Out:
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# pymssql.pyx in pymssql.Cursor.fetchall (pymssql.c:9423)()
#
# pymssql.pyx in pymssql.Cursor.getrow (pymssql.c:8322)()
#
# _mssql.pyx in _mssql.MSSQLRowIterator.__next__ (_mssql.c:4791)()
#
# _mssql.pyx in _mssql.MSSQLConnection.fetch_next_row (_mssql.c:12352)()
#
# _mssql.pyx in _mssql.check_cancel_and_raise (_mssql.c:16888)()
#
# _mssql.pyx in _mssql.maybe_raise_MSSQLDatabaseException (_mssql.c:17532)()
#
# MSSQLDatabaseException: (20004, b'DB-Lib error message 20004, severity 9:\nRead from the server failed\nNet-Lib error during Unknown error (10054)\n')
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\sqlalchemy\engine\result.py in fetchall(self)
#     963         try:
# --> 964             l = self.process_rows(self._fetchall_impl())
#     965             self._soft_close()
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\sqlalchemy\engine\result.py in _fetchall_impl(self)
#     914         try:
# --> 915             return self.cursor.fetchall()
#     916         except AttributeError:
#
# pymssql.pyx in pymssql.Cursor.fetchall (pymssql.c:9587)()
#
# OperationalError: (20004, b'DB-Lib error message 20004, severity 9:\nRead from the server failed\nNet-Lib error during Unknown error (10054)\n')
#
# During handling of the above exception, another exception occurred:
#
# MSSQLDriverException                      Traceback (most recent call last)
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _rollback_impl(self)
#     667             try:
# --> 668                 self.engine.dialect.do_rollback(self.connection)
#     669             except Exception as e:
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_rollback(self, dbapi_connection)
#     419     def do_rollback(self, dbapi_connection):
# --> 420         dbapi_connection.rollback()
#     421
#
# pymssql.pyx in pymssql.Connection.rollback (pymssql.c:5166)()
#
# pymssql.pyx in pymssql.Connection.rollback (pymssql.c:5089)()
#
# _mssql.pyx in _mssql.MSSQLConnection.execute_non_query (_mssql.c:11369)()
#
# _mssql.pyx in _mssql.MSSQLConnection.execute_non_query (_mssql.c:11191)()
#
# _mssql.pyx in _mssql.MSSQLConnection.format_and_run_query (_mssql.c:12592)()
#
# _mssql.pyx in _mssql.MSSQLConnection.cancel (_mssql.c:7502)()
#
# _mssql.pyx in _mssql.assert_connected (_mssql.c:17605)()
#
# MSSQLDriverException: Not connected to any MS SQL server
#
# The above exception was the direct cause of the following exception:
#
# DBAPIError                                Traceback (most recent call last)
# <ipython-input-2-bdd7f64c339e> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'base_query = open(\'OpenInterestEarnings.sql\', \'r\').read()\nquery_example = base_query.format(\n    window=4,\n    days_prior=1,\n    days_after=30,\n    tickers=\',\'.join(["\'AAPL\'", "\'MSFT\'", "\'C\'", "\'REGN\'"])\n)\n\nexample_earnings = query_dataframe(query_example)')
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2118             magic_arg_s = self.var_expand(line, stack_depth)
#    2119             with self.builtin_trap:
# -> 2120                 result = fn(magic_arg_s, cell)
#    2121             return result
#    2122
#
# <decorator-gen-61> in time(self, line, cell, local_ns)
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in time(self, line, cell, local_ns)
#    1175         else:
#    1176             st = clock2()
# -> 1177             exec(code, glob, local_ns)
#    1178             end = clock2()
#    1179             out = None
#
# <timed exec> in <module>()
#
# C:\Users\Bradlee Speice\Development\experimental-finance\utils\query.py in query_dataframe(query, connection)
#      17     if connection is None:
#      18         connection = get_connection()
# ---> 19     return pd.read_sql(query, connection)
#      20
#      21
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     513             sql, index_col=index_col, params=params,
#     514             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 515             chunksize=chunksize)
#     516
#     517
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1197                                         parse_dates=parse_dates)
#    1198         else:
# -> 1199             data = result.fetchall()
#    1200             frame = _wrap_result(data, columns, index_col=index_col,
#    1201                                  coerce_float=coerce_float,
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\sqlalchemy\engine\result.py in fetchall(self)
#     968             self.connection._handle_dbapi_exception(
#     969                 e, None, None,
# --> 970                 self.cursor, self.context)
#     971
#     972     def fetchmany(self, size=None):
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1332                 if cursor:
#    1333                     self._safe_close_cursor(cursor)
# -> 1334                 self._autorollback()
#    1335
#    1336             if newraise:
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _autorollback(self)
#     789     def _autorollback(self):
#     790         if not self._root.in_transaction():
# --> 791             self._root._rollback_impl()
#     792
#     793     def close(self):
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _rollback_impl(self)
#     668                 self.engine.dialect.do_rollback(self.connection)
#     669             except Exception as e:
# --> 670                 self._handle_dbapi_exception(e, None, None, None, None)
#     671             finally:
#     672                 if not self.__invalid and \
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1264                                         self.dialect.dbapi.Error,
#    1265                                         dialect=self.dialect),
# -> 1266                 exc_info
#    1267             )
#    1268         self._reentrant_error = True
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     200     exc_type, exc_value, exc_tb = exc_info
#     201     cause = exc_value if exc_value is not exception else None
# --> 202     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     203
#     204 if py3k:
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     183             value.__cause__ = cause
#     184         if value.__traceback__ is not tb:
# --> 185             raise value.with_traceback(tb)
#     186         raise value
#     187
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _rollback_impl(self)
#     666                 self.engine.logger.info("ROLLBACK")
#     667             try:
# --> 668                 self.engine.dialect.do_rollback(self.connection)
#     669             except Exception as e:
#     670                 self._handle_dbapi_exception(e, None, None, None, None)
#
# C:\Users\Bradlee Speice\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_rollback(self, dbapi_connection)
#     418
#     419     def do_rollback(self, dbapi_connection):
# --> 420         dbapi_connection.rollback()
#     421
#     422     def do_commit(self, dbapi_connection):
#
# pymssql.pyx in pymssql.Connection.rollback (pymssql.c:5166)()
#
# pymssql.pyx in pymssql.Connection.rollback (pymssql.c:5089)()
#
# _mssql.pyx in _mssql.MSSQLConnection.execute_non_query (_mssql.c:11369)()
#
# _mssql.pyx in _mssql.MSSQLConnection.execute_non_query (_mssql.c:11191)()
#
# _mssql.pyx in _mssql.MSSQLConnection.format_and_run_query (_mssql.c:12592)()
#
# _mssql.pyx in _mssql.MSSQLConnection.cancel (_mssql.c:7502)()
#
# _mssql.pyx in _mssql.assert_connected (_mssql.c:17605)()
#
# DBAPIError: (_mssql.MSSQLDriverException) Not connected to any MS SQL server

# %% [markdown]
# Assuming that does ever finish...

# %%
import pandas as pd

oi_1_20 = pd.read_csv('open_interest_1_20.csv', index_col=0)
oi_1_20['OI_Change'] = (oi_1_20['OpenInterest'] - oi_1_20['OpenInterestBefore']) / oi_1_20['OpenInterestBefore']

# %%
oi_1_20
# Out:
#           Date  Ticker  Expiration  OpenInterest  OpenInterestBefore CallPut  \
# 0   2013-07-24  AAPL    2013-08-23           9.0                 5.0       P
# 1   2013-07-24  AAPL    2013-08-23           9.0                12.0       P
# 2   2013-07-24  AAPL    2013-08-23          14.0                 5.0       P
# 3   2013-07-24  AAPL    2013-08-23          14.0                12.0       P
# 4   2013-07-24  AAPL    2013-08-23          25.0                23.0       C
# 5   2013-07-24  AAPL    2013-08-23          25.0               252.0       C
# 6   2013-07-24  AAPL    2013-08-23         508.0                23.0       C
# 7   2013-07-24  AAPL    2013-08-23         508.0               252.0       C
# 0   2013-04-24  AAPL    2013-05-24           0.0                42.0       C
# 1   2013-04-24  AAPL    2013-05-24           0.0                82.0       P
# 2   2013-04-24  AAPL    2013-05-24         141.0                42.0       C
# 3   2013-04-24  AAPL    2013-05-24         248.0                82.0       P
# 0   2013-01-24  AAPL    2013-02-22         151.0               150.0       C
# 1   2013-01-24  AAPL    2013-02-22         570.0               366.0       P
# 0   2011-10-19  AAPL    2011-11-19       13592.0             13814.0       C
# 1   2011-10-19  AAPL    2011-11-19       27517.0             26751.0       P
# 0   2011-07-20  AAPL    2011-08-20         790.0               793.0       P
# 1   2011-07-20  AAPL    2011-08-20       14166.0             15849.0       C
# 0   2011-04-21  AAPL    2011-05-21        8530.0              8365.0       P
# 1   2011-04-21  AAPL    2011-05-21       37439.0             34618.0       C
# 0   2011-01-19  AAPL    2011-02-19        5974.0              4123.0       P
# 1   2011-01-19  AAPL    2011-02-19       20153.0             15349.0       C
# 0   2013-04-19  MSFT    2013-05-18       15551.0             15344.0       P
# 1   2013-04-19  MSFT    2013-05-18      104255.0            102439.0       C
# 0   2012-07-20  MSFT    2012-08-18       15554.0             14329.0       P
# 1   2012-07-20  MSFT    2012-08-18       28702.0             28759.0       C
# 0   2012-01-20  MSFT    2012-02-18        5233.0              3315.0       P
# 1   2012-01-20  MSFT    2012-02-18       53901.0             47542.0       C
# 0   2011-10-21  MSFT    2011-11-19       15063.0             14383.0       P
# 1   2011-10-21  MSFT    2011-11-19       33764.0             32570.0       C
# ..         ...     ...         ...           ...                 ...     ...
# 0   2012-06-06  FCEL    2012-07-21         225.0               225.0       P
# 1   2012-06-06  FCEL    2012-07-21         606.0               606.0       C
# 0   2012-03-13  FCEL    2012-04-21         166.0               157.0       P
# 1   2012-03-13  FCEL    2012-04-21         892.0               690.0       C
# 0   2011-12-13  FCEL    2012-01-21         900.0               900.0       P
# 1   2011-12-13  FCEL    2012-01-21        3524.0              3503.0       C
# 0   2011-09-07  FCEL    2011-10-22         382.0               407.0       C
# 1   2011-09-07  FCEL    2011-10-22         411.0               411.0       P
# 0   2011-06-07  FCEL    2011-07-16         482.0               476.0       P
# 1   2011-06-07  FCEL    2011-07-16        4784.0              4612.0       C
# 0   2011-03-10  FCEL    2011-04-16         390.0               395.0       P
# 1   2011-03-10  FCEL    2011-04-16        1336.0              1296.0       C
# 0   2012-05-09  INFI    2012-06-16           3.0                 0.0       C
# 1   2012-05-09  INFI    2012-06-16         154.0               154.0       P
# 0   2011-11-09  INFI    2011-12-17           0.0                 0.0       C
# 1   2011-11-09  INFI    2011-12-17           0.0                 0.0       P
# 0   2011-05-11  INFI    2011-06-18           0.0                 0.0       C
# 1   2011-05-11  INFI    2011-06-18           0.0                 0.0       P
# 0   2011-03-16  INFI    2011-04-16           0.0                 0.0       C
# 1   2011-03-16  INFI    2011-04-16           0.0                 0.0       P
# 0   2012-05-09  WTI     2012-06-16           0.0                 0.0       C
# 1   2012-05-09  WTI     2012-06-16           0.0                 0.0       P
# 0   2011-11-09  TNDM    2011-12-17         141.0               141.0       P
# 1   2011-11-09  TNDM    2011-12-17         332.0               332.0       C
# 0   2011-08-10  TNDM    2011-09-17          18.0                 7.0       P
# 1   2011-08-10  TNDM    2011-09-17         107.0               101.0       C
# 0   2011-05-11  TNDM    2011-06-18         188.0               175.0       P
# 1   2011-05-11  TNDM    2011-06-18        2040.0              1402.0       C
# 0   2011-03-15  TNDM    2011-04-16          63.0                57.0       P
# 1   2011-03-15  TNDM    2011-04-16         528.0               154.0       C
#
#     Strike  StrikeDiff  ClosePrice  ClosePriceAfter  ExpirationDiff  OI_Change
# 0    440.0    0.510010  110.127502       125.589996             2.0   0.800000
# 1    440.0    0.510010  110.127502       125.589996             2.0  -0.250000
# 2    440.0    0.510010  110.127502       125.589996             2.0   1.800000
# 3    440.0    0.510010  110.127502       125.589996             2.0   0.166667
# 4    440.0    0.510010  110.127502       125.589996             2.0   0.086957
# 5    440.0    0.510010  110.127502       125.589996             2.0  -0.900794
# 6    440.0    0.510010  110.127502       125.589996             2.0  21.086957
# 7    440.0    0.510010  110.127502       125.589996             2.0   1.015873
# 0    405.0    0.462006  101.365501       110.338501             2.0  -1.000000
# 1    405.0    0.462006  101.365501       110.338501             2.0  -1.000000
# 2    405.0    0.462006  101.365501       110.338501             2.0   2.357143
# 3    405.0    0.462006  101.365501       110.338501             2.0   2.024390
# 0    450.0    0.500000  112.625000       112.702499             0.0   0.006667
# 1    450.0    0.500000  112.625000       112.702499             0.0   0.557377
# 0    400.0    1.380005   99.654999        96.192497             3.0  -0.016071
# 1    400.0    1.380005   99.654999        96.192497             3.0   0.028634
# 0    385.0    1.899994   96.724998        95.110001             3.0  -0.003783
# 1    385.0    1.899994   96.724998        95.110001             3.0  -0.106190
# 0    350.0    0.696014   87.674004        83.805000             1.0   0.019725
# 1    350.0    0.696014   87.674004        83.805000             1.0   0.081489
# 0    340.0    1.160004   84.709999        90.782501             3.0   0.448945
# 1    340.0    1.160004   84.709999        90.782501             3.0   0.312985
# 0     30.0    0.235001    1.860312         2.179375             1.0   0.013491
# 1     30.0    0.235001    1.860312         2.179375             1.0   0.017728
# 0     30.0    0.115000    1.882187         1.931250             1.0   0.085491
# 1     30.0    0.115000    1.882187         1.931250             1.0  -0.001982
# 0     30.0    0.290001    1.856875         1.953125             1.0   0.578582
# 1     30.0    0.290001    1.856875         1.953125             1.0   0.133755
# 0     27.0    0.160000    1.697500         1.581250             1.0   0.047278
# 1     27.0    0.160000    1.697500         1.581250             1.0   0.036660
# ..     ...         ...         ...              ...             ...        ...
# 0      1.0    0.060000    0.176667         0.176667            16.0   0.000000
# 1      1.0    0.060000    0.176667         0.176667            16.0   0.000000
# 0      2.0    0.320000    0.280000         0.209167            10.0   0.057325
# 1      2.0    0.320000    0.280000         0.209167            10.0   0.292754
# 0      1.0    0.080000    0.153333         0.168333            10.0   0.000000
# 1      1.0    0.080000    0.153333         0.168333            10.0   0.005995
# 0      1.0    0.290000    0.215000         0.150800            17.0  -0.061425
# 1      1.0    0.290000    0.215000         0.150800            17.0   0.000000
# 0      2.0    0.390000    0.268333         0.235000            10.0   0.012605
# 1      2.0    0.390000    0.268333         0.235000            10.0   0.037294
# 0      2.0    0.140000    0.310000         0.315000             9.0  -0.012658
# 1      2.0    0.140000    0.310000         0.315000             9.0   0.030864
# 0     12.5    0.740000   52.959999        49.400002             9.0        inf
# 1     12.5    0.740000   52.959999        49.400002             9.0   0.000000
# 0      7.5    0.170000   30.680000        35.340000             9.0        NaN
# 1      7.5    0.170000   30.680000        35.340000             9.0        NaN
# 0      7.5    0.140000   29.440001        26.200001             9.0        NaN
# 1      7.5    0.140000   29.440001        26.200001             9.0        NaN
# 0      5.0    0.330000   21.320000        22.600000             3.0        NaN
# 1      5.0    0.330000   21.320000        22.600000             3.0        NaN
# 0     17.5    0.160000   17.340000        15.770000             9.0        NaN
# 1     17.5    0.160000   17.340000        15.770000             9.0        NaN
# 0     10.0    0.000000   10.000000        10.000000             9.0   0.000000
# 1     10.0    0.000000   10.000000        10.000000             9.0   0.000000
# 0     10.0    0.830000   10.830000        10.320000             9.0   1.571429
# 1     10.0    0.830000   10.830000        10.320000             9.0   0.059406
# 0     15.0    1.129999   16.129999        16.620001             9.0   0.074286
# 1     15.0    1.129999   16.129999        16.620001             9.0   0.455064
# 0     15.0    0.920000   14.080000        14.660000             4.0   0.105263
# 1     15.0    0.920000   14.080000        14.660000             4.0   2.428571
#
# [11000 rows x 12 columns]

# %%
import numpy as np
def strategy_diverging(group, threshold=.1):
    if len(group) != 2:
        return np.nan
    # This strategy works as follows:
    # Go long when:
    #    Call Open Interest goes up by more than `threshold` pct
    #    Put Open Interest goes down by more than `threshold` pct
    # Go short when:
    #    Call Open Interest goes down by more than `threshold` pct
    #    Put Open Interest goes down by more than `threshold` pct
    call_oi_change = group[group['CallPut'] == 'C']['OI_Change'].values[0]
    put_oi_change = group[group['CallPut'] == 'P']['OI_Change'].values[0]
    
    if call_oi_change > threshold and put_oi_change < -threshold:
        return ((group['ClosePriceAfter'] - group['ClosePrice']) / group['ClosePrice']).values[0]
    elif put_oi_change > threshold and call_oi_change < -threshold:
        return ((group['ClosePrice'] - group['ClosePriceAfter']) / group['ClosePrice']).values[0]
    else:
        return 0

# %%
strategy_results = oi_1_20.groupby(['Date', 'Ticker']).apply(lambda g: strategy_diverging(g, threshold=.02))
results_df = pd.DataFrame(strategy_results, columns=['Result']).reset_index()

# %%
# %matplotlib inline
results_df['Result'].plot(kind='hist');

# %%
results_df[results_df['Result'] != 0].plot(kind='hist', bins=20);

# %%
def strategy_margin(group, margin=.05):
    if len(group) != 2:
        return np.nan
    # This strategy works as follows:
    # Go long when:
    #    Call Open Interest goes up by more than 
    #    Put Open Interest by `margin` pct
    # Go short when:
    #    Put Open Interest goes up by more than
    #    Call Open Interest by `margin` pct.
    # So for example, if Call OI goes up 2%, and Put OI
    # goes up 8%, we go short.
    # If Call OI goes up 2%, and Put OI goes down 8%,
    # we go long.
    call_oi_change = group[group['CallPut'] == 'C']['OI_Change'].values[0]
    put_oi_change = group[group['CallPut'] == 'P']['OI_Change'].values[0]
    
    if (call_oi_change - put_oi_change) > margin:
        return ((group['ClosePriceAfter'] - group['ClosePrice']) / group['ClosePrice']).values[0]
    elif (put_oi_change - call_oi_change) > margin:
        return ((group['ClosePrice'] - group['ClosePriceAfter']) / group['ClosePrice']).values[0]
    else:
        return 0

# %%
strategy_results = oi_1_20.groupby(['Date', 'Ticker']).apply(lambda g: strategy_margin(g, margin=.02))
results_df = pd.DataFrame(strategy_results, columns=['Result']).reset_index()

# %%
# %matplotlib inline
results_df['Result'].plot(kind='hist');

# %%
results_df[(results_df['Result'] != 0) & (results_df['Result'].abs() < 1)]['Result'].mean()
# Out:
# -0.0028104488344770206

# %% [markdown]
# # Trying to pull data manually for testing

# %%
import pandas as pd
earnings_dates = pd.read_csv('all_earnings.csv', index_col=0)

# %%
pairs = (earnings_dates.groupby(['Date', 'Ticker'])
         .apply(lambda g: (g['Ticker'].values[0], g['Date'].values[0]))
         .reset_index()[0])

# %%
pd.DataFrame(list(pairs), columns=['Ticker', 'Date'])
# Out:
#       Ticker        Date
# 0       CVGW  2011-01-03
# 1       ANGO  2011-01-04
# 2       CAMP  2011-01-04
# 3       LNDC  2011-01-04
# 4        MOS  2011-01-04
# 5       NEOG  2011-01-04
# 6       SONC  2011-01-04
# 7       TISI  2011-01-04
# 8         FC  2011-01-05
# 9       RECN  2011-01-05
# 10        RT  2011-01-05
# 11      SHLM  2011-01-05
# 12       WOR  2011-01-05
# 13       GPN  2011-01-06
# 14       MON  2011-01-06
# 15       MSM  2011-01-06
# 16       RPM  2011-01-06
# 17      SCHN  2011-01-06
# 18       STZ  2011-01-06
# 19       AZZ  2011-01-07
# 20       GBX  2011-01-07
# 21       KBH  2011-01-07
# 22      PSMT  2011-01-07
# 23        AA  2011-01-10
# 24      APOL  2011-01-10
# 25       AYI  2011-01-10
# 26      HELE  2011-01-10
# 27      WDFC  2011-01-10
# 28       FUL  2011-01-11
# 29       LEN  2011-01-11
# ...      ...         ...
# 19059     NX  2013-12-18
# 19060   ORCL  2013-12-18
# 19061   PAYX  2013-12-18
# 19062    SCS  2013-12-18
# 19063    ACN  2013-12-19
# 19064    AIR  2013-12-19
# 19065    ATU  2013-12-19
# 19066    CAG  2013-12-19
# 19067    CCL  2013-12-19
# 19068   CTAS  2013-12-19
# 19069    DRI  2013-12-19
# 19070    KBH  2013-12-19
# 19071    LUB  2013-12-19
# 19072    MCS  2013-12-19
# 19073   NEOG  2013-12-19
# 19074    NKE  2013-12-19
# 19075    PIR  2013-12-19
# 19076    RAD  2013-12-19
# 19077    RHT  2013-12-19
# 19078   SCHL  2013-12-19
# 19079    WGO  2013-12-19
# 19080    WOR  2013-12-19
# 19081   FINL  2013-12-20
# 19082    KMX  2013-12-20
# 19083    NAV  2013-12-20
# 19084    WBA  2013-12-20
# 19085   CAMP  2013-12-23
# 19086    EBF  2013-12-23
# 19087   CALM  2013-12-30
# 19088    BSX  2013-12-31
#
# [19089 rows x 2 columns]
